# %%
import pandas as pd

# %%
df = pd.read_csv('/project2/ishanu/YI_terror/data/terror.csv')
# Out:
# /software/python-3.7.0-el7-x86_64/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,6,31,33,53,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_sub = df[ (df['iyear'] >= 2012) & (df['iyear'] <= 2016) ].copy()
df_sub.to_csv('/project2/ishanu/YI_terror/data/terror_2012-2016.csv')

# %%
df_sub.sort_values(by=['iyear', 'imonth', 'iday'])
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 104654  201201010001   2012       1     1                  NaN         0
# 104655  201201010002   2012       1     1                  NaN         0
# 104656  201201010003   2012       1     1                  NaN         0
# 104657  201201010004   2012       1     1                  NaN         0
# 104658  201201010005   2012       1     1                  NaN         1
# 104659  201201010006   2012       1     1                  NaN         0
# 104660  201201010007   2012       1     1                  NaN         0
# 104661  201201010008   2012       1     1                  NaN         0
# 104662  201201010009   2012       1     1                  NaN         0
# 104663  201201010012   2012       1     1  2012-01-01 00:00:00         0
# 104664  201201010013   2012       1     1                  NaN         0
# 104665  201201010014   2012       1     1                  NaN         0
# ...

# %%
for col in df_sub.columns:
    print(col)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
df_sub['attacktype1_txt'].unique()
# Out:
# array(['Bombing/Explosion', 'Armed Assault',
#        'Hostage Taking (Kidnapping)', 'Assassination',
#        'Facility/Infrastructure Attack', 'Unknown', 'Hijacking',
#        'Unarmed Assault', 'Hostage Taking (Barricade Incident)'],
#       dtype=object)
